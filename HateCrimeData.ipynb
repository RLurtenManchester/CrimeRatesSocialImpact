# %% [markdown]
# ## Import packages and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Question 1: Dynamic of victims of hate crimes, 5 years

# %% [markdown]
# # 2015 Dataset

# %%
HateCrimes2015 = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2015.xls")
HateCrimes2015
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 0   Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                            by Bias Motivation, 2015        NaN        NaN
# 2                                     Bias motivation  Incidents   Offenses
# 3                                               Total       5850       6885
# 4                               Single-Bias Incidents       5818       6837
# 5                            Race/Ethnicity/Ancestry:       3310       4029
# 6                                          Anti-White        613        734
# 7                      Anti-Black or African American       1745       2125
# 8               Anti-American Indian or Alaska Native        131        137
# 9                                          Anti-Asian        111        132
# 10     Anti-Native Hawaiian or Other Pacific Islander          4          6
# ...

# %% [markdown]
# ## Lets start by trimming this down to just the numbers and see how it goes.

# %%
HateCrimes2015A = HateCrimes2015[3:45]
HateCrimes2015A
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 3                                               Total       5850       6885
# 4                               Single-Bias Incidents       5818       6837
# 5                            Race/Ethnicity/Ancestry:       3310       4029
# 6                                          Anti-White        613        734
# 7                      Anti-Black or African American       1745       2125
# 8               Anti-American Indian or Alaska Native        131        137
# 9                                          Anti-Asian        111        132
# 10     Anti-Native Hawaiian or Other Pacific Islander          4          6
# 11                         Anti-Multiple Races, Group        113        138
# 12                                          Anti-Arab         37         47
# 13                            Anti-Hispanic or Latino        299        379
# ...

# %%
HateCrimes2015A.columns = ["BiasMotivation", "Incidents", "Offenses", "Victims", "Offenders"]
HateCrimes2015A.head()
# Out:
#                    BiasMotivation Incidents Offenses Victims Offenders
# 3                           Total      5850     6885    7173      5493
# 4           Single-Bias Incidents      5818     6837    7121      5475
# 5        Race/Ethnicity/Ancestry:      3310     4029    4216      3196
# 6                      Anti-White       613      734     789       681
# 7  Anti-Black or African American      1745     2125    2201      1605

# %%
HateCrimes2015B = HateCrimes2015A[[ "Incidents", "Offenses", "Victims", "Offenders"]]
HateCrimes2015B.head()
# Out:
#   Incidents Offenses Victims Offenders
# 3      5850     6885    7173      5493
# 4      5818     6837    7121      5475
# 5      3310     4029    4216      3196
# 6       613      734     789       681
# 7      1745     2125    2201      1605

# %% [markdown]
# ### Ok now we are down to just the numbers, lets look for some correlation and turn this into a heat map

# %%
HateCrimes2015B.corr(method='pearson')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sns.pairplot(HateCrimes2015B)

# %%
HateCrimes2015B['Victims'].hist()
# Out:
# <AxesSubplot:>

# %%
HateCrimes2015B['Offenders'].hist()
# Out:
# <AxesSubplot:>

# %%
HateCrimes2015_CrossTab = pd.crosstab(HateCrimes2015A['BiasMotivation'], HateCrimes2015A['Victims'])

# %%
HateCrimes2015_CrossTab
# Out:
# Victims                                             1     2     5     6     \
# BiasMotivation
# Anti-American Indian or Alaska Native                  0     0     0     0
# Anti-Arab                                              0     0     0     0
# Anti-Asian                                             0     0     0     0
# Anti-Atheism/Agnosticism/etc.                          0     1     0     0
# Anti-Bisexual                                          0     0     0     0
# Anti-Black or African American                         0     0     0     0
# Anti-Buddhist                                          1     0     0     0
# Anti-Catholic                                          0     0     0     0
# Anti-Eastern Orthodox (Russian, Greek, Other)          0     0     0     0
# Anti-Female                                            0     0     0     0
# Anti-Gay (Male)                                        0     0     0     0
# ...

# %%
## Well that didnt do what I wanted it to... lets keep working with this stuff... |

# %%
HateCrimes2015B["Victims"].corr(HateCrimes2015B["Offenders"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f4d231185caa> in <module>
# ----> 1 HateCrimes2015B["Victims"].corr(HateCrimes2015B["Offenders"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2319
#    2320         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2321             return nanops.nancorr(
#    2322                 this.values, other.values, method=method, min_periods=min_periods
#    2323             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ...

# %%
display(HateCrimes2015B.dtypes)
# Out:
# Incidents    object
# Offenses     object
# Victims      object
# Offenders    object
# dtype: object

# %%
HateCrimes2015B['Incidents']= HateCrimes2015B['Incidents'].astype(int)
# Out:
# <ipython-input-25-0a8180686542>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2015B['Incidents']= HateCrimes2015B['Incidents'].astype(int)

# %%
HateCrimes2015B['Offenses']= HateCrimes2015B['Offenses'].astype(int)
HateCrimes2015B['Victims']= HateCrimes2015B['Victims'].astype(int)
HateCrimes2015B['Offenders']= HateCrimes2015B['Offenders'].astype(int)
# Out:
# <ipython-input-26-d919c0fe4113>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2015B['Offenses']= HateCrimes2015B['Offenses'].astype(int)
# <ipython-input-26-d919c0fe4113>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2015B['Victims']= HateCrimes2015B['Victims'].astype(int)
# <ipython-input-26-d919c0fe4113>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
display(HateCrimes2015B.dtypes)
# Out:
# Incidents    int32
# Offenses     int32
# Victims      int32
# Offenders    int32
# dtype: object

# %% [markdown]
# ## Ah that should make all this work better

# %%
HateCrimes2015B.corr(method='pearson')
# Out:
#            Incidents  Offenses   Victims  Offenders
# Incidents   1.000000  0.999781  0.999752   0.997685
# Offenses    0.999781  1.000000  0.999992   0.998219
# Victims     0.999752  0.999992  1.000000   0.998228
# Offenders   0.997685  0.998219  0.998228   1.000000

# %%
sns.heatmap(HateCrimes2015B, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(HateCrimes2015B)

# %% [markdown]
# ## Ok so after all that transformation, that didnt change things much...

# %% [markdown]
# # 2016 Dataset
# ### This will be wrangled similarly to the set above

# %%
HateCrimes2016 = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2016.xls")
HateCrimes2016
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 0   Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                            by Bias Motivation, 2016        NaN        NaN
# 2                                     Bias motivation  Incidents   Offenses
# 3                                               Total       6121       7321
# 4                               Single-Bias Incidents       6063       7227
# 5                            Race/Ethnicity/Ancestry:       3489       4229
# 6                                          Anti-White        720        876
# 7                      Anti-Black or African American       1739       2122
# 8               Anti-American Indian or Alaska Native        154        161
# 9                                          Anti-Asian        113        131
# 10     Anti-Native Hawaiian or Other Pacific Islander          9          9
# ...

# %%
HateCrimes2016A = HateCrimes2016[3:45]
HateCrimes2016A.head()
# Out:
#                          Table 1  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                           Total       6121       7321       7615       5770
# 4           Single-Bias Incidents       6063       7227       7509       5727
# 5        Race/Ethnicity/Ancestry:       3489       4229       4426       3383
# 6                      Anti-White        720        876        909        831
# 7  Anti-Black or African American       1739       2122       2220       1588
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7
# 3         NaN         NaN        NaN
# 4         NaN         NaN        NaN
# 5         NaN         NaN        NaN
# 6         NaN         NaN        NaN
# 7         NaN         NaN        NaN

# %%
HateCrimes2016A.columns = ["BiasMotivation", "Incidents", "Offenses", "Victims", "Offenders", "", "", ""]
HateCrimes2016A.head()
# Out:
#                    BiasMotivation Incidents Offenses Victims Offenders      \
# 3                           Total      6121     7321    7615      5770 NaN
# 4           Single-Bias Incidents      6063     7227    7509      5727 NaN
# 5        Race/Ethnicity/Ancestry:      3489     4229    4426      3383 NaN
# 6                      Anti-White       720      876     909       831 NaN
# 7  Anti-Black or African American      1739     2122    2220      1588 NaN
#
#
# 3 NaN  NaN
# 4 NaN  NaN
# 5 NaN  NaN
# 6 NaN  NaN
# 7 NaN  NaN

# %%
HateCrimes2016B = HateCrimes2016A[[ "Incidents", "Offenses", "Victims", "Offenders"]]
HateCrimes2016B.head()
# Out:
#   Incidents Offenses Victims Offenders
# 3      6121     7321    7615      5770
# 4      6063     7227    7509      5727
# 5      3489     4229    4426      3383
# 6       720      876     909       831
# 7      1739     2122    2220      1588

# %%
HateCrimes2016B['Incidents']= HateCrimes2016B['Incidents'].astype(int) 
HateCrimes2016B['Offenses']= HateCrimes2016B['Offenses'].astype(int)
HateCrimes2016B['Victims']= HateCrimes2016B['Victims'].astype(int)
HateCrimes2016B['Offenders']= HateCrimes2016B['Offenders'].astype(int)
# Out:
# <ipython-input-43-8d5d1add03dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2016B['Incidents']= HateCrimes2016B['Incidents'].astype(int)
# <ipython-input-43-8d5d1add03dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2016B['Offenses']= HateCrimes2016B['Offenses'].astype(int)
# <ipython-input-43-8d5d1add03dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.pairplot(HateCrimes2015B)

# %% [markdown]
# # 2017 Dataset
# ## Same wrangling as the others

# %%
HateCrimes2017 = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2017.xls")
HateCrimes2017
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 0   Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                            by Bias Motivation, 2017        NaN        NaN
# 2                                     Bias motivation  Incidents   Offenses
# 3                                               Total       7175       8437
# 4                               Single-Bias Incidents       7106       8126
# 5                            Race/Ethnicity/Ancestry:       4131       4832
# 6                                          Anti-White        741        844
# 7                      Anti-Black or African American       2013       2358
# 8               Anti-American Indian or Alaska Native        251        281
# 9                                          Anti-Asian        131        152
# 10     Anti-Native Hawaiian or Other Pacific Islander         16         17
# ...

# %%
HateCrimes2017A = HateCrimes2017[3:45]
HateCrimes2017A
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 3                                               Total       7175       8437
# 4                               Single-Bias Incidents       7106       8126
# 5                            Race/Ethnicity/Ancestry:       4131       4832
# 6                                          Anti-White        741        844
# 7                      Anti-Black or African American       2013       2358
# 8               Anti-American Indian or Alaska Native        251        281
# 9                                          Anti-Asian        131        152
# 10     Anti-Native Hawaiian or Other Pacific Islander         16         17
# 11                         Anti-Multiple Races, Group        180        215
# 12                                          Anti-Arab        102        128
# 13                            Anti-Hispanic or Latino        427        525
# ...

# %%
HateCrimes2017A.columns = ["BiasMotivation", "Incidents", "Offenses", "Victims", "Offenders"]
HateCrimes2017A.head()
# Out:
#                    BiasMotivation Incidents Offenses Victims Offenders
# 3                           Total      7175     8437    8828      6370
# 4           Single-Bias Incidents      7106     8126    8493      6307
# 5        Race/Ethnicity/Ancestry:      4131     4832    5060      3747
# 6                      Anti-White       741      844     864       758
# 7  Anti-Black or African American      2013     2358    2458      1742

# %%
HateCrimes2017B = HateCrimes2017A[[ "Incidents", "Offenses", "Victims", "Offenders"]]
HateCrimes2017B.head()
# Out:
#   Incidents Offenses Victims Offenders
# 3      7175     8437    8828      6370
# 4      7106     8126    8493      6307
# 5      4131     4832    5060      3747
# 6       741      844     864       758
# 7      2013     2358    2458      1742

# %%
HateCrimes2017B['Incidents']= HateCrimes2017B['Incidents'].astype(int) 
HateCrimes2017B['Offenses']= HateCrimes2017B['Offenses'].astype(int)
HateCrimes2017B['Victims']= HateCrimes2017B['Victims'].astype(int)
HateCrimes2017B['Offenders']= HateCrimes2017B['Offenders'].astype(int)
# Out:
# <ipython-input-50-c6a06de9d5a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2017B['Incidents']= HateCrimes2017B['Incidents'].astype(int)
# <ipython-input-50-c6a06de9d5a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2017B['Offenses']= HateCrimes2017B['Offenses'].astype(int)
# <ipython-input-50-c6a06de9d5a6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.pairplot(HateCrimes2017B)

# %% [markdown]
# # 2018 Dataset
# ## Wrangling the same way

# %%
HateCrimes2018 = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2018.xls")
HateCrimes2018
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 0   Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                            by Bias Motivation, 2018        NaN        NaN
# 2                                     Bias motivation  Incidents   Offenses
# 3                                               Total       7120       8496
# 4                               Single-Bias Incidents       7036       8327
# 5                            Race/Ethnicity/Ancestry:       4047       4954
# 6                                          Anti-White        762       1001
# 7                      Anti-Black or African American       1943       2325
# 8               Anti-American Indian or Alaska Native        194        204
# 9                                          Anti-Asian        148        171
# 10     Anti-Native Hawaiian or Other Pacific Islander         20         26
# ...

# %% [markdown]
# ## This one seems to have some 'junk' on it...

# %%
HateCrimes2018A = HateCrimes2018[3:45]
HateCrimes2018A
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 3                                               Total       7120       8496
# 4                               Single-Bias Incidents       7036       8327
# 5                            Race/Ethnicity/Ancestry:       4047       4954
# 6                                          Anti-White        762       1001
# 7                      Anti-Black or African American       1943       2325
# 8               Anti-American Indian or Alaska Native        194        204
# 9                                          Anti-Asian        148        171
# 10     Anti-Native Hawaiian or Other Pacific Islander         20         26
# 11                         Anti-Multiple Races, Group        137        166
# 12                                          Anti-Arab         82        100
# 13                            Anti-Hispanic or Latino        485        644
# ...

# %%
HateCrimes2018A.columns = ["BiasMotivation", "Incidents", "Offenses", "Victims", "Offenders", "", "", "", "", ""]
HateCrimes2018A.head()
# Out:
#                    BiasMotivation Incidents Offenses Victims Offenders      \
# 3                           Total      7120     8496    8819      6266 NaN
# 4           Single-Bias Incidents      7036     8327    8646      6188 NaN
# 5        Race/Ethnicity/Ancestry:      4047     4954    5155      3634 NaN
# 6                      Anti-White       762     1001    1038       754 NaN
# 7  Anti-Black or African American      1943     2325    2426      1707 NaN
#
#
# 3 NaN NaN NaN  NaN
# 4 NaN NaN NaN  NaN
# 5 NaN NaN NaN  NaN
# 6 NaN NaN NaN  NaN
# 7 NaN NaN NaN  NaN

# %%
HateCrimes2018B = HateCrimes2015A[[ "Incidents", "Offenses", "Victims", "Offenders"]]
HateCrimes2018B.head()
# Out:
#   Incidents Offenses Victims Offenders
# 3      5850     6885    7173      5493
# 4      5818     6837    7121      5475
# 5      3310     4029    4216      3196
# 6       613      734     789       681
# 7      1745     2125    2201      1605

# %%
HateCrimes2018B['Incidents']= HateCrimes2018B['Incidents'].astype(int) 
HateCrimes2018B['Offenses']= HateCrimes2018B['Offenses'].astype(int)
HateCrimes2018B['Victims']= HateCrimes2018B['Victims'].astype(int)
HateCrimes2018B['Offenders']= HateCrimes2018B['Offenders'].astype(int)
# Out:
# <ipython-input-56-c0207875a394>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2018B['Incidents']= HateCrimes2018B['Incidents'].astype(int)
# <ipython-input-56-c0207875a394>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2018B['Offenses']= HateCrimes2018B['Offenses'].astype(int)
# <ipython-input-56-c0207875a394>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.pairplot(HateCrimes2018B)

# %% [markdown]
# # 2019 Dataset
# ### Just a little more wrangling...

# %%
HateCrimes2019 = pd.read_excel("Table_1_Incidents_Offenses_Victims_and_Known_Offenders_by_Bias_Motivation_2019.xls")

# %%
HateCrimes2019.head()
# Out:
#                                             Table 1  Unnamed: 1 Unnamed: 2  \
# 0  Incidents, Offenses, Victims, and Known Offenders        NaN        NaN
# 1                           by Bias Motivation, 2019        NaN        NaN
# 2                                    Bias motivation  Incidents   Offenses
# 3                                              Total       7314       8559
# 4                              Single-Bias Incidents       7103       8302
#
#   Unnamed: 3         Unnamed: 4
# 0        NaN                NaN
# 1        NaN                NaN
# 2   Victims1  Known\noffenders2
# 3       8812               6406
# 4       8552               6268

# %%
HateCrimes2019A = HateCrimes2019[3:45]
HateCrimes2019A
# Out:
#                                              Table 1  Unnamed: 1 Unnamed: 2  \
# 3                                               Total       7314       8559
# 4                               Single-Bias Incidents       7103       8302
# 5                            Race/Ethnicity/Ancestry:       3963       4784
# 6                                          Anti-White        666        755
# 7                      Anti-Black or African American       1930       2314
# 8               Anti-American Indian or Alaska Native        119        126
# 9                                          Anti-Asian        158        205
# 10     Anti-Native Hawaiian or Other Pacific Islander         21         25
# 11                         Anti-Multiple Races, Group        134        171
# 12                                          Anti-Arab         95        122
# 13                            Anti-Hispanic or Latino        527        676
# ...

# %%
HateCrimes2019A.columns = ["BiasMotivation", "Incidents", "Offenses", "Victims", "Offenders"]
HateCrimes2019A.head()
# Out:
#                    BiasMotivation Incidents Offenses Victims Offenders
# 3                           Total      7314     8559    8812      6406
# 4           Single-Bias Incidents      7103     8302    8552      6268
# 5        Race/Ethnicity/Ancestry:      3963     4784    4930      3550
# 6                      Anti-White       666      755     775       645
# 7  Anti-Black or African American      1930     2314    2391      1682

# %%
HateCrimes2019B = HateCrimes2015A[[ "Incidents", "Offenses", "Victims", "Offenders"]]
HateCrimes2019B.head()
# Out:
#   Incidents Offenses Victims Offenders
# 3      5850     6885    7173      5493
# 4      5818     6837    7121      5475
# 5      3310     4029    4216      3196
# 6       613      734     789       681
# 7      1745     2125    2201      1605

# %%
HateCrimes2019B['Incidents']= HateCrimes2019B['Incidents'].astype(int) 
HateCrimes2019B['Offenses']= HateCrimes2019B['Offenses'].astype(int)
HateCrimes2019B['Victims']= HateCrimes2019B['Victims'].astype(int)
HateCrimes2019B['Offenders']= HateCrimes2019B['Offenders'].astype(int)
# Out:
# <ipython-input-63-06b6948671e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2019B['Incidents']= HateCrimes2019B['Incidents'].astype(int)
# <ipython-input-63-06b6948671e8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HateCrimes2019B['Offenses']= HateCrimes2019B['Offenses'].astype(int)
# <ipython-input-63-06b6948671e8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.pairplot(HateCrimes2019B)

# %% [markdown]
# ## Some basic observations... If a hate crimes is committed it is most likely anti-black or anti-jewish
