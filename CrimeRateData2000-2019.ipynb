# %%
import pandas as pd

# %% [markdown]
# # Question 4: How have the homicide rates changed nationwide over the last decade? (This data luckily shows 20 years of data so we can see an even bigger picture)

# %% [markdown]
# # Loading in the Crime Rate per 100000 data set from 2000-2019

# %%
CrimeRatePer100000 = pd.read_excel("Table_1_Crime_in_the_United_States_by_Volume_and_Rate_per_100000_Inhabitants_2000-2019.xls")

# %%
CrimeRatePer100000.head()
# Out:
#                                              Table 1               \
# 0                         Crime in the United States          NaN
# 1  by Volume and Rate per 100,000 Inhabitants, 20...          NaN
# 2                                               Year  Population1
# 3                                               2000    281421906
# 4                                              20015    285317559
#
#         Unnamed: 2               Unnamed: 3  \
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2  Violent\ncrime2  Violent \ncrime \nrate
# 3          1425486                    506.5
# 4          1439480                    504.5
#
#                                 Unnamed: 4  \
# 0                                      NaN
# 1                                      NaN
# 2  Murder and\nnonnegligent \nmanslaughter
# 3                                    15586
# 4                                    16037
#
# ...

# %% [markdown]
# ## Column Titles are in the wrong space, lets fix that

# %%
CrimeRatePer100000.columns = ["Year", "Population", "ViolentCrime", "ViolentCrimeRate", "Murder/NonNegligentManslaughter", "Murder/NonNegligentManslaughterRate", "Rape/RevisedDefinition", "Rape/RevisedDefinitionRate", "Rape/LegacyDefinition", "Rape/LegacyDefinitionRate", "Robbery", "RoberryRate", "AggravatedAssault", "AggravatedAssaultRate", "PropertyCrime", "PropertyCrimeRate", "Burglary", "BurglaryRate", "Larceny/Theft", "Larceny/TheftRate", "MotorVehicleTheft", "MotorVehicleTheftRate", "", ""]

# %%
CrimeRatePer100000.head()
# Out:
#                                                 Year   Population  \
# 0                         Crime in the United States          NaN
# 1  by Volume and Rate per 100,000 Inhabitants, 20...          NaN
# 2                                               Year  Population1
# 3                                               2000    281421906
# 4                                              20015    285317559
#
#       ViolentCrime         ViolentCrimeRate  \
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2  Violent\ncrime2  Violent \ncrime \nrate
# 3          1425486                    506.5
# 4          1439480                    504.5
#
#            Murder/NonNegligentManslaughter  \
# 0                                      NaN
# 1                                      NaN
# 2  Murder and\nnonnegligent \nmanslaughter
# 3                                    15586
# 4                                    16037
#
# ...

# %% [markdown]
# ## Ok, that's better but lets cut out the first 2 columns that were really just the title of the dataset

# %%
CrimeRatePer100000A = CrimeRatePer100000[3:24]

# %%
CrimeRatePer100000A.head()
# Out:
#     Year Population ViolentCrime ViolentCrimeRate  \
# 3   2000  281421906      1425486            506.5
# 4  20015  285317559      1439480            504.5
# 5   2002  287973924      1423677            494.4
# 6   2003  290788976      1383676            475.8
# 7   2004  293656842      1360088            463.2
#
#   Murder/NonNegligentManslaughter Murder/NonNegligentManslaughterRate  \
# 3                           15586                                 5.5
# 4                           16037                                 5.6
# 5                           16229                                 5.6
# 6                           16528                                 5.7
# 7                           16148                                 5.5
#
#   Rape/RevisedDefinition Rape/RevisedDefinitionRate Rape/LegacyDefinition  \
# 3                    NaN                        NaN                 90178
# 4                    NaN                        NaN                 90863
# ...

# %%
CrimeRatePer100000A['Murder/NonNegligentManslaughterRate'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ok so that is definitely not normally distributed

# %%
CrimeRatePer100000A['Murder/NonNegligentManslaughter'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Lets look at this data and see what hits us for the last 20 years...

# %% [markdown]
# ### Well that needs a little more wrangling to make that happen... lets do that now
# #### I'm going to split this into a subset of the rates and the actual numbers for the data

# %%
CrimeRatePer100000B = CrimeRatePer100000A[["Year", "ViolentCrime", "Murder/NonNegligentManslaughter", "Rape/LegacyDefinition", "Robbery", "AggravatedAssault", "PropertyCrime", "Burglary", "Larceny/Theft", "MotorVehicleTheft"]]
CrimeRatePer100000B.head()
# Out:
#     Year ViolentCrime Murder/NonNegligentManslaughter Rape/LegacyDefinition  \
# 3   2000      1425486                           15586                 90178
# 4  20015      1439480                           16037                 90863
# 5   2002      1423677                           16229                 95235
# 6   2003      1383676                           16528                 93883
# 7   2004      1360088                           16148                 95089
#
#   Robbery AggravatedAssault PropertyCrime Burglary Larceny/Theft  \
# 3  408016            911706      10182584  2050992       6971590
# 4  423557            909023      10437189  2116531       7092267
# 5  420806            891407      10455277  2151252       7057379
# 6  414235            859030      10442862  2154834       7026802
# 7  401470            847381      10319386  2144446       6937089
#
#   MotorVehicleTheft
# 3           1160002
# 4           1228391
# 5           1246646
# 6           1261226
# ...

# %%
CrimeRatePer100000C = CrimeRatePer100000A[["Year", "ViolentCrimeRate", "Murder/NonNegligentManslaughterRate", "Rape/LegacyDefinitionRate", "RoberryRate", "AggravatedAssaultRate", "PropertyCrimeRate", "BurglaryRate", "Larceny/TheftRate", "MotorVehicleTheftRate"]]
CrimeRatePer100000C.head()
# Out:
#     Year ViolentCrimeRate Murder/NonNegligentManslaughterRate  \
# 3   2000            506.5                                 5.5
# 4  20015            504.5                                 5.6
# 5   2002            494.4                                 5.6
# 6   2003            475.8                                 5.7
# 7   2004            463.2                                 5.5
#
#   Rape/LegacyDefinitionRate RoberryRate AggravatedAssaultRate  \
# 3                        32         145                   324
# 4                      31.8       148.5                 318.6
# 5                      33.1       146.1                 309.5
# 6                      32.3       142.5                 295.4
# 7                      32.4       136.7                 288.6
#
#   PropertyCrimeRate BurglaryRate Larceny/TheftRate MotorVehicleTheftRate
# 3            3618.3        728.8            2477.3                 412.2
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(CrimeRatePer100000B)

# %% [markdown]
# ## This looks a little interesting and like something I need to explore a little more

# %%
sns.pairplot(CrimeRatePer100000C)

# %% [markdown]
# ## This has some things I didn't expect using the rates of crimes across the board
